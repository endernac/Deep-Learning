# %%
#Adapted from https://towardsdatascience.com/implementing-word2vec-in-pytorch-skip-gram-model-e6bae040d2fb
# and https://github.com/jojonki/word2vec-pytorch/blob/master/word2vec.ipynb

# see http://pytorch.org/tutorials/beginner/nlp/word_embeddings_tutorial.html
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

torch.manual_seed(1)

# %%
# Text is lightly adapted (removing punctuation and possesives) from The Raven by Edgar Allan Poe
text = """ Once upon a midnight dreary while I pondered weak and weary
 Over many a quaint and curious volume of forgotten lore
 While I nodded nearly napping suddenly there came a tapping
 As of some one gently rapping rapping at my chamber door
 This is some visiter I muttered tapping at my chamber door
                          Only this and nothing more

 Ah distinctly I remember it was in the bleak December
 And each separate dying ember wrought its ghost upon the floor
 Eagerly I wished the morrow vainly I had sought to borrow
 From my books surcease of sorrow sorrow for the lost Lenore
 For the rare and radiant maiden whom the angels name Lenore
                          Nameless here for evermore

 And the silken sad uncertain rustling of each purple curtain
 Thrilled me filled me with fantastic terrors never felt before
 So that now to still the beating of my heart I stood repeating
 This is some visiter entreating entrance at my chamber door
 Some late visiter entreating entrance at my chamber door
                          This it is and nothing more

 Presently my soul grew stronger hesitating then no longer
 Sir said I or Madam truly your forgiveness I implore
 But the fact is I was napping and so gently you came rapping
 And so faintly you came tapping tapping at my chamber door
 That I scarce was sure I heard you here I opened wide the door
                          Darkness there and nothing more

 Deep into that darkness peering long I stood there wondering fearing
 Doubting dreaming dreams no mortal ever dared to dream before
 But the silence was unbroken and the darkness gave no token
 And the only word there spoken was the whispered word Lenore
 This I whispered and an echo murmured back the word Lenore
                          Merely this and nothing more

 Back into the chamber turning all my soul within me burning
 Soon I heard again a tapping somewhat louder than before
 Surely said I surely that is something at my window lattice
 Let me see then what thereat is and this mystery explore
 Let my heart be still a moment and this mystery explore
                          This is the wind and nothing more

 Open here I flung the shutter when with many a flirt and flutter
 In there stepped a stately raven of the saintly days of yore
 Not the least obeisance made he not an instant stopped or stayed he
 But with mien of lord or lady perched above my chamber door
 Perched upon a bust of Pallas just above my chamber door
                          Perched and sat and nothing more

 Then this ebony bird beguiling my sad fancy into smiling
 By the grave and stern decorum of the countenance it wore
 Though thy crest be shorn and shaven thou I said art sure no craven
 Ghastly grim and ancient raven wandering from the Nightly shore
 Tell me what thy lordly name is on the Night Plutonian shore
                          Quoth the raven Nevermore

 Much I marvelled this ungainly fowl to hear discourse so plainly
 Though its answer little meaninglittle relevancy bore
 For we cannot help agreeing that no living human being
 Ever yet was blessed with seeing bird above his chamber door
 Bird or beast upon the sculptured bust above his chamber door
                         With such name as Nevermore

 But the raven sitting lonely on the placid bust spoke only
 That one word as if his soul in that one word he did outpour
 Nothing farther then he utterednot a feather then he fluttered
 Till I scarcely more than muttered Other friends have flown before
 On the morrow he will leave me as my hopes have flown before
                          Then the bird said Nevermore

 Startled at the stillness broken by reply so aptly spoken
 Doubtless said I what it utters is its only stock and store
 Caught from some unhappy master whom unmerciful Disaster
 Followed fast and followed faster till his songs one burden bore
 Till the dirges of his Hope that melancholy burden bore
                         Of Never nevermore

 But the raven still beguiling all my sad soul into smiling
 Straight I wheeled a cushioned seat in front of bird and bust and door
 Then upon the velvet sinking I betook myself to thinking
 Fancy unto fancy thinking what this ominous bird of yore
 What this grim ungainly ghastly gaunt and ominous bird of yore
                         Meant in croaking Nevermore

 This I sat engaged in guessing but no syllable expressing
 To the fowl whose fiery eyes now burned into my bosom core
 This and more I sat divining with my head at ease reclining
 On the cushion velvet lining that the lamplght gloated over
 But whose velvet violet lining with the lamplight gloating over
                          She shall press ah nevermore

 Then me thought the air grew denser perfumed from an unseen censer
 Swung by Angels whose faint foot-falls tinkled on the tufted floor
 Wretch I cried thy God hath lent theeby these angels he hath sent
 thee
 Respite respite and nepenthe from thy memories of Lenore
 Quaff oh quaff this kind nepenthe and forget this lost Lenore
                           Quoth the raven Nevermore

 Prophet said I thing of evil prophet still if bird or devil
 Whether Tempter sent or whether tempest tossed thee here ashore
 Desolate yet all undaunted on this desert land enchanted
 On this home by Horror haunted tell me truly I implore
 Is there is there balm in Gilead tell me tell me I implore
                           Quoth the raven Nevermore

 Prophet said I thing of evil prophet still if bird or devil
 By that Heaven that bends above us by that God we both adore
 Tell this soul with sorrow laden if within the distant Aidenn
 It shall clasp a sainted maiden whom the angels name Lenore
 Clasp a rare and radiant maiden whom the angels name Lenore
                           Quoth the raven Nevermore

 Be that word our sign of parting bird or fiend I shrieked upstarting
 Get thee back into the tempest and the Night Plutonian shore
 Leave no black plume as a token of that lie thy soul hath spoken
 Leave my loneliness unbroken quit the bust above my door
 Take thy beak from out my heart and take thy form from off my door
                          Quoth the raven Nevermore

 And the raven never flitting still is sitting still is sitting
 On the pallid bust of Pallas just above my chamber door
 And his eyes have all the seeming of a demon that is dreaming
 And the lamp-light over him streaming throws his shadow on the floor
 And my soul from out that shadow that lies floating on the floor
                          Shall be lifted nevermore""".lower().split()

# %%
# context window size is two
CONTEXT_SIZE = 2  # 2 words to the left, 2 to the right

# We find the unique words of the corpus so that we can create our vocabulary
vocab = set(text)
vocab_size = len(vocab)
print('vocab_size:', vocab_size)


# Build a dictionary so that each word in vocabualary is assigned a number and 
# and we can map each number back to the word
w2i = {w: i for i, w in enumerate(vocab)}
i2w = {i: w for i, w in enumerate(vocab)}
print(w2i)
# Out:
# vocab_size: 435
# {'grave': 0, 'remember': 1, 'god': 2, 'parting': 3, 'to': 4, 'lies': 5, 'that': 6, 'tapping': 7, 'ever': 8, 'madam': 9, 'grim': 10, 'will': 11, 'other': 12, 'ebony': 13, 'obeisance': 14, 'was': 15, 'dying': 16, 'syllable': 17, 'betook': 18, 'sculptured': 19, 'silence': 20, 'my': 21, 'presently': 22, 'muttered': 23, 'stately': 24, 'shadow': 25, 'cannot': 26, 'all': 27, 'though': 28, 'gently': 29, 'dreaming': 30, 'lonely': 31, 'filled': 32, 'songs': 33, 'discourse': 34, 'pallid': 35, 'flutter': 36, 'sainted': 37, 'head': 38, 'no': 39, 'repeating': 40, 'longer': 41, 'aidenn': 42, 'tempter': 43, 'december': 44, 'wondering': 45, 'shall': 46, 'lie': 47, 'burned': 48, 'implore': 49, 'your': 50, 'quit': 51, 'our': 52, 'out': 53, 'when': 54, 'straight': 55, 'uncertain': 56, 'moment': 57, 'lent': 58, 'me': 59, 'sat': 60, 'sorrow': 61, 'terrors': 62, 'fantastic': 63, 'shaven': 64, 'ghost': 65, 'startled': 66, 'seeming': 67, 'seat': 68, 'broken': 69, 'wandering': 70, 'his': 71, 'evil': 72, 'cushion': 73, 'fiery': 74, 'visiter': 75, 'borrow': 76, 'flung': 77, 'art': 78, 'sitting': 79, 'eyes': 80, 'from': 81, 'human': 82, 'bosom': 83, 'theeby': 84, 'felt': 85, 'if': 86, 'enchanted': 87, 'thereat': 88, 'just': 89, 'some': 90, 'nightly': 91, 'unmerciful': 92, 'unbroken': 93, 'tufted': 94, 'entreating': 95, 'over': 96, 'bore': 97, 'sad': 98, 'haunted': 99, 'ungainly': 100, 'midnight': 101, 'somewhat': 102, 'forgiveness': 103, 'he': 104, 'night': 105, 'land': 106, 'distant': 107, 'tell': 108, 'expressing': 109, 'explore': 110, 'thy': 111, 'floor': 112, 'sought': 113, 'again': 114, 'gloated': 115, 'but': 116, 'countenance': 117, 'made': 118, 'ancient': 119, 'quaint': 120, 'not': 121, 'lamplght': 122, 'soul': 123, 'you': 124, 'ghastly': 125, 'mortal': 126, 'laden': 127, 'heart': 128, 'dreary': 129, 'quoth': 130, 'as': 131, 'darkness': 132, 'myself': 133, 'back': 134, 'within': 135, 'came': 136, 'morrow': 137, 'lamplight': 138, 'while': 139, 'least': 140, 'yore': 141, 'quaff': 142, 'plutonian': 143, 'marvelled': 144, 'crest': 145, 'flitting': 146, 'press': 147, 'purple': 148, 'only': 149, 'relevancy': 150, 'off': 151, 'these': 152, 'spoken': 153, 'soon': 154, 'said': 155, 'lordly': 156, 'each': 157, 'grew': 158, 'rustling': 159, 'home': 160, 'living': 161, 'peering': 162, 'have': 163, 'spoke': 164, 'throws': 165, 'tempest': 166, 'token': 167, 'placid': 168, 'at': 169, 'thrilled': 170, 'its': 171, 'fast': 172, 'respite': 173, 'whether': 174, 'of': 175, 'stopped': 176, 'hear': 177, 'craven': 178, 'lost': 179, 'vainly': 180, 'scarce': 181, 'evermore': 182, 'napping': 183, 'prophet': 184, 'kind': 185, 'plume': 186, 'smiling': 187, 'late': 188, 'bleak': 189, 'fearing': 190, 'wheeled': 191, 'nodded': 192, 'ah': 193, 'burden': 194, 'faintly': 195, 'many': 196, 'sent': 197, 'more': 198, 'door': 199, 'wretch': 200, 'surely': 201, 'eagerly': 202, 'wished': 203, 'rare': 204, 'doubtless': 205, 'unto': 206, 'let': 207, 'beast': 208, 'censer': 209, 'above': 210, 'wrought': 211, 'disaster': 212, 'fact': 213, 'shorn': 214, 'hesitating': 215, 'denser': 216, 'still': 217, 'stillness': 218, 'separate': 219, 'i': 220, 'then': 221, 'fiend': 222, 'unseen': 223, 'thee': 224, 'in': 225, 'reply': 226, 'floating': 227, 'form': 228, 'curious': 229, 'radiant': 230, 'entrance': 231, 'volume': 232, 'aptly': 233, 'being': 234, 'bends': 235, 'nevermore': 236, 'murmured': 237, 'melancholy': 238, 'see': 239, 'utters': 240, 'bust': 241, 'beguiling': 242, 'echo': 243, 'shutter': 244, 'is': 245, 'did': 246, 'followed': 247, 'gilead': 248, 'doubting': 249, 'front': 250, 'black': 251, 'desolate': 252, 'stock': 253, 'lamp-light': 254, 'beating': 255, 'so': 256, 'divining': 257, 'saintly': 258, 'raven': 259, 'gaunt': 260, 'stayed': 261, 'meant': 262, 'him': 263, 'hopes': 264, 'ominous': 265, 'lady': 266, 'whose': 267, 'faint': 268, 'for': 269, 'guessing': 270, 'this': 271, 'flown': 272, 'had': 273, 'cushioned': 274, 'never': 275, 'dreams': 276, 'or': 277, 'open': 278, 'ease': 279, 'angel ...

# %% [markdown]
# ![Continuous bag of words vs. skipgram model](https://raw.githubusercontent.com/jojonki/word2vec-pytorch/master/word2vec.PNG)
#
# Image from https://github.com/jojonki/word2vec-pytorch

# %%
# Tuple of an array of words (the context) to a word (the target)
def create_cbow_dataset(text):
    data = []
    for i in range(2, len(text) - 2):
        context = [text[i - 2], text[i - 1],
                   text[i + 1], text[i + 2]]
        target = text[i]
        data.append((context, target))
    return data

cbow_train = create_cbow_dataset(text)
print('cbow sample', cbow_train[0])
# Out:
# cbow sample (['once', 'upon', 'midnight', 'dreary'], 'a')

# %%
# Simple 3 layer network to map target word to an array of probabilities for 
# each word being in its context
# Note that the first layer is a special layer - an embedding layer 
# It maps the one-hot encoded vocabulary to a vector of a fixed size 
class CBOW(nn.Module):
    def __init__(self, vocab_size, embd_size, context_size, hidden_size):
        super(CBOW, self).__init__()
        self.embeddings = nn.Embedding(vocab_size, embd_size)
        self.linear1 = nn.Linear(2*context_size*embd_size, hidden_size)
        self.linear2 = nn.Linear(hidden_size, vocab_size)
        
    def forward(self, inputs):
        embedded = self.embeddings(inputs).view((1, -1))
        out = F.relu(self.linear1(embedded))
        out = self.linear2(out)
        log_probs = F.log_softmax(out)
        return log_probs

# %%
embd_size = 100
learning_rate = 0.01
n_epoch = 30

def train_cbow():
    hidden_size = 64
    losses = []
    loss_fn = nn.NLLLoss()
    model = CBOW(vocab_size, embd_size, CONTEXT_SIZE, hidden_size)
    print(model)
    optimizer = optim.SGD(model.parameters(), lr=learning_rate)


    for epoch in range(n_epoch):
        total_loss = 0
        print("epoch: ", epoch+1)
        for context, target in cbow_train:
            # convert words to numerical tokens
            context_num = torch.tensor([w2i[w] for w in context], dtype=torch.long)

            # run context ids through model
            model.zero_grad()
            log_probs = model(context_num).view(1, -1)

            # get loss and take step
            loss = loss_fn(log_probs, torch.tensor([w2i[target]], dtype=torch.long))
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            
        losses.append(total_loss)
        print("Loss: ", total_loss)
        print()

    return model, losses

cbow_model, cbow_losses = train_cbow()
# Out:
# CBOW(
#   (embeddings): Embedding(435, 100)
#   (linear1): Linear(in_features=400, out_features=64, bias=True)
#   (linear2): Linear(in_features=64, out_features=435, bias=True)
# )
# epoch:  1
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   app.launch_new_instance()
# Loss:  6243.768977046013
#
# epoch:  2
# Loss:  4875.787678640336
#
# epoch:  3
# Loss:  3778.032315235585
#
# epoch:  4
# Loss:  2705.676634949632
#
# epoch:  5
# Loss:  1714.2740016593016
#
# epoch:  6
# Loss:  901.082789152184
#
# epoch:  7
# Loss:  383.4595543439482
#
# epoch:  8
# Loss:  168.54770425514107
#
# epoch:  9
# Loss:  99.24847282996507
#
# epoch:  10
# Loss:  72.77164084132437
#
# epoch:  11
# Loss:  58.34926448879969
#
# epoch:  12
# Loss:  49.05541762389498
#
# epoch:  13
# Loss:  42.43211947137979
#
# epoch:  14
# Loss:  37.482543065430036
#
# epoch:  15
# Loss:  33.684373238811304
#
# epoch:  16
# Loss:  30.576496485320604
#
# epoch:  17
# Loss:  28.03219044708794
#
# epoch:  18
# Loss:  25.921638621037005
#
# epoch:  19
# Loss:  24.175676578012144
#
# epoch:  20
# Loss:  22.68695617818821
#
# epoch:  21
# Loss:  21.370507252359403
#
# epoch:  22
# Loss:  20.19999726551464
#
# epoch:  23
# Loss:  19.424013952622545
#
# epoch:  24
# Loss:  18.303202191245646
#
# epoch:  25
# Loss:  17.436184475319124
#
# epoch:  26
# Loss:  16.706772545565684
#
# epoch:  27
# Loss:  16.055269796286495
#
# epoch:  28
# Loss:  15.581290350860684
#
# epoch:  29
# Loss:  14.967083702249795
#
# epoch:  30
# Loss:  14.445926184184657

# %%
# You have to use the other dataset for test, but in this case I use training data 
# because this dataset is too small
def test_cbow(test_data, model):
    print('====Test CBOW===')
    correct_ct = 0
    for ctx, target in test_data:
        ctx_idxs = [w2i[w] for w in ctx]
        ctx_var = torch.LongTensor(ctx_idxs)

        model.zero_grad()
        log_probs = model(ctx_var)
        _, predicted = torch.max(log_probs.view(1,-1), 1)
        
        predicted_word = i2w[predicted.item()]
        print('predicted:', predicted_word, ' label:', target)
        if predicted_word == target:
            correct_ct += 1
    
    print('Accuracy: {:.1f}% ({:d}/{:d})'.format(correct_ct/len(test_data)*100, correct_ct, len(test_data)))

test_cbow(cbow_train, cbow_model)
# Out:
# ====Test CBOW===
# predicted: a  label: a
# predicted: midnight  label: midnight
# predicted: dreary  label: dreary
# predicted: while  label: while
# predicted: i  label: i
# predicted: pondered  label: pondered
# predicted: weak  label: weak
# predicted: and  label: and
# predicted: weary  label: weary
# predicted: over  label: over
# predicted: many  label: many
# predicted: a  label: a
# predicted: quaint  label: quaint
# predicted: and  label: and
# predicted: curious  label: curious
# predicted: volume  label: volume
# predicted: of  label: of
# predicted: forgotten  label: forgotten
# predicted: lore  label: lore
# predicted: while  label: while
# predicted: i  label: i
# predicted: nodded  label: nodded
# predicted: nearly  label: nearly
# predicted: napping  label: napping
# predicted: suddenly  label: suddenly
# predicted: there  label: there
# predicted: came  label: came
# predicted: a  label: a
# predicted: tapping  label: tapping
# predicted: as  label: as
# predicted: of  label: of
# predicted: some  label: some
# predicted: one  label: one
# predicted: gently  label: gently
# predicted: rapping  label: rapping
# predicted: rapping  label: rapping
# predicted: at  label: at
# predicted: my  label: my
# predicted: chamber  label: chamber
# predicted: door  label: door
# predicted: this  label: this
# predicted: is  label: is
# predicted: some  label: some
# predicted: visiter  label: visiter
# predicted: i  label: i
# predicted: muttered  label: muttered
# predicted: tapping  label: tapping
# predicted: at  label: at
# predicted: my  label: my
# predicted: chamber  label: chamber
# predicted: door  label: door
# predicted: only  label: only
# predicted: this  label: this
# predicted: and  label: and
# predicted: nothing  label: nothing
# predicted: more  label: more
# predicted: ah  label: ah
# predicted: distinctly  label: distinctly
# predicted: i  label: i
# predicted: remember  label: remember
# predicted: it  label: it
# predicted: was  label: was
# predicted: in  label: in
# predicted: the  label: the
# predicted: bleak  label: bleak
# predicted: december  label: december
# predicted: and  label: and
# predicted: each  label: each
# predicted: separate  label: separate
# predicted: dying  label: dying
# predicted: ember  label: ember
# predicted: wrought  label: wrought
# predicted: its  label: its
# predicted: ghost  label: ghost
# predicted: upon  label: upon
# predicted: the  label: the
# predicted: floor  label: floor
# predicted: eagerly  label: eagerly
# predicted: i  label: i
# predicted: wished  label: wished
# predicted: the  label: the
# predicted: morrow  label: morrow
# predicted: vainly  label: vainly
# predicted: i  label: i
# predicted: had  label: had
# predicted: sought  label: sought
# predicted: to  label: to
# predicted: borrow  label: borrow
# predicted: from  label: from
# predicted: my  label: my
# predicted: books  label: books
# predicted: surcease  label: surcease
# predicted: of  label: of
# predicted: sorrow  label: sorrow
# predicted: sorrow  label: sorrow
# predicted: for  label: for
# predicted: the  label: the
# predicted: lost  label: lost
# predicted: lenore  label: lenore
# predicted: for  label: for
# predicted: the  label: the
# predicted: rare  label: rare
# predicted: and  label: and
# predicted: radiant  label: radiant
# predicted: maiden  label: maiden
# predicted: whom  label: whom
# predicted: the  label: the
# predicted: angels  label: angels
# predicted: name  label: name
# predicted: lenore  label: lenore
# predicted: nameless  label: nameless
# predicted: here  label: here
# predicted: for  label: for
# predicted: evermore  label: evermore
# predicted: and  label: and
# predicted: the  label: the
# predicted: silken  label: silken
# predicted: sad  label: sad
# predicted: uncertain  label: uncertain
# predicted: rustling  label: rustling
# predicted: of  label: of
# predicted: each  label: each
# predicted: purple  label: purple
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   app.launch_new_instance()
# predicted: curtain  label: curtain
# predicted: thrilled  label: thrilled
# predicted: me  label: me
# predicted: filled  label: filled
# predicted: me  label: me
# predicted: with  label: with
# predicted: fantastic  label: fantastic
# predicted: terrors  label: terrors
# predicted: never  label: never
# predicted: felt  label: felt
# predicted: before  label: before
# predicted: so  label: so
# predicted: that  label: that
# predicted: now  label: now
# predicted: to  label: to
# predicted: still  label: still
# predicted: the  label: the
# predicted: beating  label: beating
# predicted: of  label: of
# predicted: my  label: my
# predicted: heart  label: heart
# predicted: i  label: i
# predicted: stood  label: stood
# predicted: repeating  label: repeating
# predicted: this  label: this
# predicted: is  label: is
# predicted: some  label: some
# predicted: visiter  label: visiter
# predicted: entreating  label: entreating
# predicted: entrance  label: entrance
# predicted: at  label: at
# predicted: my  label: my
# predicted: chamber  label: chamber
# predicted: door  label: door
# predicted: some  label: some
# predicted: late  label: late
# predicted: visiter  label: visiter
# predicted: entreating  label: entreating
# predicted: entrance  label: entrance
# predicted: at  label: at
# predicted: my  label: my
# predicted: chamber  label: chamber
# predicted: door  label: door
# predicted: this  label: this
# predicted: it  label: it
# predicted: is  label: is
# predicted: and  label: and
# predicted: nothing  label: nothing
# predicted: more  label: more
# predicted: presently  label: presently
# predicted: my  label: my
# predicted: soul  label: soul
# predicted: grew  label: grew
# predicted: stronger  label: stronger
# predicted: hesitating  label: hesitating
# predicted: then  label: then
# predicted: no  label: no
# predicted: longer  label: longer
# predicted: sir  label: sir
# predicted: said  label: said
# predicted: i  label: i
# predicted: or  label: or
# predicted: madam  label: madam
# predicted: truly  label: truly
# predicted: your  label: your
# predicted: forgiveness  label: forgiveness
# predicted: i  label: i
# predicted: implore  label: implore
# predicted: but  label: but
# predicted: the  label: the
# predicted: fact  label: fact
# predicted: is  label: is
# predicted: i  label: i
# predicted: was  label: was
# predicted: napping  label: napping
# predicted: and  label: and
# predicted: so  label: so
# predicted: faintly  label: gently
# predicted: you  label: you
# predicted: came  label: came
# predicted: rapping  label: rapping
# predicted: and  label: and
# predicted: so  label: so
# predicted: faintly  label: faintly
# predicted: you  label: you
# predicted: came  label: came
# predicted: tapping  label: tapping
# predicted: tapping  label: tapping
# predicted: at  label: at
# predicted: my  label: my
# predicted: chamber  label: chamber
# predicted: door  label: door
# predicted: that  label: that
# predicted: i  label: i
# predicted: scarce  label: scarce
# predicted: was  label: was
# predicted: sure  label: sure
# predicted: i  label: i
# predicted: heard  label: heard
# predicted: you  label: you
# predicted: here  label: here
# predicted: i  label: i
# predicted: opened  label: opened
# predicted: wide  label: wide
# predicted: the  label: the
# predicted: door  label: door
# predicted: darkness  label: darkness
# predicted: there  label: there
# predicted: and  label: and
# predicted: nothing  label: nothing
# predicted: more  label: more
# predicted: deep  label: deep
# predicted: into  label: into
# predicted: that  label: that
# predicted: darkness  label: darkness
# predicted: peering  label: peering
# predicted: long  label: long
# predicted: i  label: i
# predicted: stood  label: stood
# predicted: there  label: there
# predicted: wondering  label: wondering
# predicted: fearing  label: fearing
# predicted: doubting  label: doubting
# predicted: dreaming  label: dreaming
# predicted: dreams  label: dreams
# predicted: no  label: no
# predicted: mortal  label: mortal
# predicted: ever  label: ever
# predicted: dared  label: dared
# predicted: to  label: to
# predicted: dream  label: dream
# predicted: before  label: before
# predicted: but  label: but
# predicted: the  label: the
# predicted: silence  label: silence
# predicted: was  label: was
# predicted: unbroken  label: unbroken
# predicted: and  label: and
# predicted: the  label: the
# predicted: darkness  label: darkness
# predicted: gave  label: gave
# predicted: no  label: no
# predicted: token  label: token
# predicted: and  label: and
# predicted: the  label: the
# predicted: only  label: only
# predicted: word  label: word
# predicted: there  label: there
# predicted: spoken  label: spoken
# predicted: was  label: was
# predicted: the  label: the
# predicted: whispered  label: whispered
# predicted: word  label: word
# predicted: lenore  label: lenore
# predicted: this  label: this
# predicted: i  label: i
# predicted: whispered  label: whispered
# predicted: and  label: and
# predicted: an  label: an
# predicted: echo  label: echo
# predicted: murmured  label: murmured
# predicted: back  label: back
# predicted: the  label: the
# predicted: word  label: word
# predicted: lenore  label: lenore
# predicted: merely  label: merely
# predicted: this  label: this
# predicted: and  label: and
# predicted: nothing  label: nothing
# predicted: more  label: more
# predicted: back  label: back
# predicted: into  label: into
# predicted: the  label: the
# predicted: chamber  label: chamber
# predicted: turning  label: turning
# predicted: all  label: all
# predicted: my  label: my
# predicted: soul  label: soul
# predicted: within  label: within
# predicted: me  label: me
# predicted: burning  label: burning
# predicted: soon  label: soon
# predicted: i  label: i
# predicted: heard  label: heard
# predicted: again  label: again
# predicted: a  label: a
# predicted: tapping  label: tapping
# predicted: somewhat  label: somewhat
# predicted: louder  label: louder
# predicted: than  label: than
# predicted: before  label: before
# predicted: surely  label: surely
# predicted: said  label: said
# predicted: i  label: i
# predicted: surely  label: surely
# predicted: that  label: that
# predicted: is  label: is
# predicted: something  label: something
# predicted: at  label: at
# predicted: my  label: my
# predicted: window  label: window
# predicted: lattice  label: lattice
# predicted: let  label: let
# predicted: me  label: me
# predicted: see  label: see
# predicted: then  label: then
# predicted: what  label: what
# predicted: thereat  label: thereat
# predicted: is  label: is
# predicted: and  label: and
# predicted: this  label: this
# predicted: mystery  label: mystery
# predicted: explore  label: explore
# predicted: let  label: let
# predicted: my  label: my
# predicted: heart  label: heart
# predicted: be  label: be
# predicted: still  label: still
# predicted: a  label: a
# predicted: moment  label: moment
# predicted: and  label: and
# predicted: this  label: this
# predicted: mystery  label: mystery
# predicted: explore  label: explore
# predicted: this  label: this
# predicted: is  label: is
# predicted: the  label: the
# predicted: wind  label: wind
# predicted: and  label: and
# predicted: nothing  label: nothing
# predicted: more  label: more
# predicted: open  label: open
# predicted: here  label: here
# predicted: i  label: i
# predicted: flung  label: flung
# predicted: the  label: the
# predicted: shutter  label: shutter
# predicted: when  label: when
# predicted: with  label: with
# predicted: many  label: many
# predicted: a  label: a
# predicted: flirt  label: flirt
# predicted: and  label: and
# predicted: flutter  label: flutter
# predicted: in  label: in
# predicted: there  label: there
# predicted: stepped  label: stepped
# predicted: a  label: a
# predicted: stately  label: stately
# predicted: raven  label: raven
# predicted: of  label: of
# predicted: the  label: the
# predicted: saintly  label: saintly
# predicted: days  label: days
# predicted: of  label: of
# predicted: yore  label: yore
# predicted: not  label: not
# predicted: the  label: the
# predicted: least  label: least
# predicted: obeisance  label: obeisance
# predicted: made  label: made
# predicted: he  label: he
# predicted: not  label: not
# predicted: an  label: an
# predicted: instant  label: instant
# predicted: stopped  label: stopped
# predicted: or  label: or
# predicted: stayed  label: stayed
# predicted: he  label: he
# predicted: but  label: but
# predicted: with  label: with
# predicted: mien  label: mien
# predicted: of  label: of
# predicted: lord  label: lord
# predicted: or  label: or
# predicted: lady  label: lady
# predicted: perched  label: perched
# predicted: above  label: above
# predicted: my  label: my
# predicted: chamber  label: chamber
# predicted: door  label: door
# predicted: perched  label: perched
# predicted: upon  label: upon
# predicted: a  label: a
# predicted: bust  label: bust
# predicted: of  label: of
# predicted: pallas  label: pallas
# predicted: just  label: just
# predicted: above  label: above
# predicted: my  label: my
# predicted: chamber  label: chamber
# predicted: door  label: door
# predicted: perched  label: perched
# predicted: and  label: and
# predicted: sat  label: sat
# predicted: and  label: and
# predicted: nothing  label: nothing
# predicted: more  label: more
# predicted: then  label: then
# predicted: this  label: this
# predicted: ebony  label: ebony
# predicted: bird  label: bird
# predicted: beguiling  label: beguiling
# predicted: my  label: my
# predicted: sad  label: sad
# predicted: soul  label: fancy
# predicted: into  label: into
# predicted: smiling  label: smiling
# predicted: by  label: by
# predicted: the  label: the
# predicted: grave  label: grave
# predicted: and  label: and
# predicted: stern  label: stern
# predicted: decorum  label: decorum
# predicted: of  label: of
# predicted: the  label: the
# predicted: countenance  label: countenance
# predicted: it  label: it
# predicted: wore  label: wore
# predicted: though  label: though
# predicted: thy  label: thy
# predicted: crest  label: crest
# predicted: be  label: be
# predicted: shorn  label: shorn
# predicted: and  label: and
# predicted: shaven  label: shaven
# predicted: thou  label: thou
# predicted: i  label: i
# predicted: said  label: said
# predicted: art  label: art
# predicted: sure  label: sure
# predicted: no  label: no
# predicted: craven  label: craven
# predicted: ghastly  label: ghastly
# predicted: grim  label: grim
# predicted: and  label: and
# predicted: ancient  label: ancient
# predicted: raven  label: raven
# predicted: wandering  label: wandering
# predicted: from  label: from
# predicted: the  label: the
# predicted: nightly  label: nightly
# predicted: shore  label: shore
# predicted: tell  label: tell
# predicted: me  label: me
# predicted: what  label: what
# predicted: thy  label: thy
# predicted: lordly  label: lordly
# predicted: name  label: name
# predicted: is  label: is
# predicted: on  label: on
# predicted: the  label: the
# predicted: night  label: night
# predicted: plutonian  label: plutonian
# predicted: shore  label: shore
# predicted: quoth  label: quoth
# predicted: the  label: the
# predicted: raven  label: raven
# predicted: nevermore  label: nevermore
# predicted: much  label: much
# predicted: i  label: i
# predicted: marvelled  label: marvelled
# predicted: this  label: this
# predicted: ungainly  label: ungainly
# predicted: fowl  label: fowl
# predicted: to  label: to
# predicted: hear  label: hear
# predicted: discourse  label: discourse
# predicted: so  label: so
# predicted: plainly  label: plainly
# predicted: though  label: though
# predicted: its  label: its
# predicted: answer  label: answer
# predicted: little  label: little
# predicted: meaninglittle  label: meaninglittle
# predicted: relevancy  label: relevancy
# predicted: bore  label: bore
# predicted: for  label: for
# predicted: we  label: we
# predicted: cannot  label: cannot
# predicted: help  label: help
# predicted: agreeing  label: agreeing
# predicted: that  label: that
# predicted: no  label: no
# predicted: living  label: living
# predicted: human  label: human
# predicted: being  label: being
# predicted: ever  label: ever
# predicted: yet  label: yet
# predicted: was  label: was
# predicted: blessed  label: blessed
# predicted: with  label: with
# predicted: seeing  label: seeing
# predicted: bird  label: bird
# predicted: above  label: above
# predicted: his  label: his
# predicted: chamber  label: chamber
# predicted: door  label: door
# predicted: bird  label: bird
# predicted: or  label: or
# predicted: beast  label: beast
# predicted: upon  label: upon
# predicted: the  label: the
# predicted: sculptured  label: sculptured
# predicted: bust  label: bust
# predicted: above  label: above
# predicted: his  label: his
# predicted: chamber  label: chamber
# predicted: door  label: door
# predicted: with  label: with
# predicted: such  label: such
# predicted: name  label: name
# predicted: as  label: as
# predicted: nevermore  label: nevermore
# predicted: but  label: but
# predicted: the  label: the
# predicted: raven  label: raven
# predicted: sitting  label: sitting
# predicted: lonely  label: lonely
# predicted: on  label: on
# predicted: the  label: the
# predicted: placid  label: placid
# predicted: bust  label: bust
# predicted: spoke  label: spoke
# predicted: only  label: only
# predicted: that  label: that
# predicted: one  label: one
# predicted: word  label: word
# predicted: as  label: as
# predicted: if  label: if
# predicted: his  label: his
# predicted: soul  label: soul
# predicted: in  label: in
# predicted: that  label: that
# predicted: one  label: one
# predicted: word  label: word
# predicted: he  label: he
# predicted: did  label: did
# predicted: outpour  label: outpour
# predicted: nothing  label: nothing
# predicted: farther  label: farther
# predicted: then  label: then
# predicted: he  label: he
# predicted: utterednot  label: utterednot
# predicted: a  label: a
# predicted: feather  label: feather
# predicted: then  label: then
# predicted: he  label: he
# predicted: fluttered  label: fluttered
# predicted: till  label: till
# predicted: i  label: i
# predicted: scarcely  label: scarcely
# predicted: more  label: more
# predicted: than  label: than
# predicted: muttered  label: muttered
# predicted: other  label: other
# predicted: friends  label: friends
# predicted: have  label: have
# predicted: flown  label: flown
# predicted: before  label: before
# predicted: on  label: on
# predicted: the  label: the
# predicted: morrow  label: morrow
# predicted: he  label: he
# predicted: will  label: will
# predicted: leave  label: leave
# predicted: me  label: me
# predicted: as  label: as
# predicted: my  label: my
# predicted: hopes  label: hopes
# predicted: have  label: have
# predicted: flown  label: flown
# predicted: before  label: before
# predicted: then  label: then
# predicted: the  label: the
# predicted: bird  label: bird
# predicted: said  label: said
# predicted: nevermore  label: nevermore
# predicted: startled  label: startled
# predicted: at  label: at
# predicted: the  label: the
# predicted: stillness  label: stillness
# predicted: broken  label: broken
# predicted: by  label: by
# predicted: reply  label: reply
# predicted: so  label: so
# predicted: aptly  label: aptly
# predicted: spoken  label: spoken
# predicted: doubtless  label: doubtless
# predicted: said  label: said
# predicted: i  label: i
# predicted: what  label: what
# predicted: it  label: it
# predicted: utters  label: utters
# predicted: is  label: is
# predicted: its  label: its
# predicted: only  label: only
# predicted: stock  label: stock
# predicted: and  label: and
# predicted: store  label: store
# predicted: caught  label: caught
# predicted: from  label: from
# predicted: some  label: some
# predicted: unhappy  label: unhappy
# predicted: master  label: master
# predicted: whom  label: whom
# predicted: unmerciful  label: unmerciful
# predicted: disaster  label: disaster
# predicted: followed  label: followed
# predicted: fast  label: fast
# predicted: and  label: and
# predicted: followed  label: followed
# predicted: faster  label: faster
# predicted: till  label: till
# predicted: his  label: his
# predicted: songs  label: songs
# predicted: one  label: one
# predicted: burden  label: burden
# predicted: bore  label: bore
# predicted: till  label: till
# predicted: the  label: the
# predicted: dirges  label: dirges
# predicted: of  label: of
# predicted: his  label: his
# predicted: hope  label: hope
# predicted: that  label: that
# predicted: melancholy  label: melancholy
# predicted: burden  label: burden
# predicted: bore  label: bore
# predicted: of  label: of
# predicted: never  label: never
# predicted: nevermore  label: nevermore
# predicted: but  label: but
# predicted: the  label: the
# predicted: raven  label: raven
# predicted: still  label: still
# predicted: beguiling  label: beguiling
# predicted: all  label: all
# predicted: my  label: my
# predicted: sad  label: sad
# predicted: soul  label: soul
# predicted: into  label: into
# predicted: smiling  label: smiling
# predicted: straight  label: straight
# predicted: i  label: i
# predicted: wheeled  label: wheeled
# predicted: a  label: a
# predicted: cushioned  label: cushioned
# predicted: seat  label: seat
# predicted: in  label: in
# predicted: front  label: front
# predicted: of  label: of
# predicted: bird  label: bird
# predicted: and  label: and
# predicted: bust  label: bust
# predicted: and  label: and
# predicted: door  label: door
# predicted: then  label: then
# predicted: upon  label: upon
# predicted: the  label: the
# predicted: velvet  label: velvet
# predicted: sinking  label: sinking
# predicted: i  label: i
# predicted: betook  label: betook
# predicted: myself  label: myself
# predicted: to  label: to
# predicted: thinking  label: thinking
# predicted: fancy  label: fancy
# predicted: unto  label: unto
# predicted: fancy  label: fancy
# predicted: thinking  label: thinking
# predicted: what  label: what
# predicted: this  label: this
# predicted: ominous  label: ominous
# predicted: bird  label: bird
# predicted: of  label: of
# predicted: yore  label: yore
# predicted: what  label: what
# predicted: this  label: this
# predicted: grim  label: grim
# predicted: ungainly  label: ungainly
# predicted: ghastly  label: ghastly
# predicted: gaunt  label: gaunt
# predicted: and  label: and
# predicted: ominous  label: ominous
# predicted: bird  label: bird
# predicted: of  label: of
# predicted: yore  label: yore
# predicted: meant  label: meant
# predicted: in  label: in
# predicted: croaking  label: croaking
# predicted: nevermore  label: nevermore
# predicted: this  label: this
# predicted: i  label: i
# predicted: sat  label: sat
# predicted: engaged  label: engaged
# predicted: in  label: in
# predicted: guessing  label: guessing
# predicted: but  label: but
# predicted: no  label: no
# predicted: syllable  label: syllable
# predicted: expressing  label: expressing
# predicted: to  label: to
# predicted: the  label: the
# predicted: fowl  label: fowl
# predicted: whose  label: whose
# predicted: fiery  label: fiery
# predicted: eyes  label: eyes
# predicted: now  label: now
# predicted: burned  label: burned
# predicted: into  label: into
# predicted: my  label: my
# predicted: bosom  label: bosom
# predicted: core  label: core
# predicted: this  label: this
# predicted: and  label: and
# predicted: more  label: more
# predicted: i  label: i
# predicted: sat  label: sat
# predicted: divining  label: divining
# predicted: with  label: with
# predicted: my  label: my
# predicted: head  label: head
# predicted: at  label: at
# predicted: ease  label: ease
# predicted: reclining  label: reclining
# predicted: on  label: on
# predicted: the  label: the
# predicted: cushion  label: cushion
# predicted: velvet  label: velvet
# predicted: lining  label: lining
# predicted: that  label: that
# predicted: the  label: the
# predicted: lamplght  label: lamplght
# predicted: gloated  label: gloated
# predicted: over  label: over
# predicted: but  label: but
# predicted: whose  label: whose
# predicted: velvet  label: velvet
# predicted: violet  label: violet
# predicted: lining  label: lining
# predicted: with  label: with
# predicted: the  label: the
# predicted: lamplight  label: lamplight
# predicted: gloating  label: gloating
# predicted: over  label: over
# predicted: she  label: she
# predicted: shall  label: shall
# predicted: press  label: press
# predicted: ah  label: ah
# predicted: nevermore  label: nevermore
# predicted: then  label: then
# predicted: me  label: me
# predicted: thought  label: thought
# predicted: the  label: the
# predicted: air  label: air
# predicted: grew  label: grew
# predicted: denser  label: denser
# predicted: perfumed  label: perfumed
# predicted: from  label: from
# predicted: an  label: an
# predicted: unseen  label: unseen
# predicted: censer  label: censer
# predicted: swung  label: swung
# predicted: by  label: by
# predicted: angels  label: angels
# predicted: whose  label: whose
# predicted: faint  label: faint
# predicted: foot-falls  label: foot-falls
# predicted: tinkled  label: tinkled
# predicted: on  label: on
# predicted: the  label: the
# predicted: tufted  label: tufted
# predicted: floor  label: floor
# predicted: wretch  label: wretch
# predicted: i  label: i
# predicted: cried  label: cried
# predicted: thy  label: thy
# predicted: god  label: god
# predicted: hath  label: hath
# predicted: lent  label: lent
# predicted: theeby  label: theeby
# predicted: these  label: these
# predicted: angels  label: angels
# predicted: he  label: he
# predicted: hath  label: hath
# predicted: sent  label: sent
# predicted: thee  label: thee
# predicted: respite  label: respite
# predicted: respite  label: respite
# predicted: and  label: and
# predicted: nepenthe  label: nepenthe
# predicted: from  label: from
# predicted: thy  label: thy
# predicted: memories  label: memories
# predicted: of  label: of
# predicted: lenore  label: lenore
# predicted: quaff  label: quaff
# predicted: oh  label: oh
# predicted: quaff  label: quaff
# predicted: this  label: this
# predicted: kind  label: kind
# predicted: nepenthe  label: nepenthe
# predicted: and  label: and
# predicted: forget  label: forget
# predicted: this  label: this
# predicted: lost  label: lost
# predicted: lenore  label: lenore
# predicted: quoth  label: quoth
# predicted: the  label: the
# predicted: raven  label: raven
# predicted: nevermore  label: nevermore
# predicted: prophet  label: prophet
# predicted: said  label: said
# predicted: i  label: i
# predicted: thing  label: thing
# predicted: of  label: of
# predicted: evil  label: evil
# predicted: prophet  label: prophet
# predicted: still  label: still
# predicted: if  label: if
# predicted: bird  label: bird
# predicted: or  label: or
# predicted: devil  label: devil
# predicted: whether  label: whether
# predicted: tempter  label: tempter
# predicted: sent  label: sent
# predicted: or  label: or
# predicted: whether  label: whether
# predicted: tempest  label: tempest
# predicted: tossed  label: tossed
# predicted: thee  label: thee
# predicted: here  label: here
# predicted: ashore  label: ashore
# predicted: desolate  label: desolate
# predicted: yet  label: yet
# predicted: all  label: all
# predicted: undaunted  label: undaunted
# predicted: on  label: on
# predicted: this  label: this
# predicted: desert  label: desert
# predicted: land  label: land
# predicted: enchanted  label: enchanted
# predicted: on  label: on
# predicted: this  label: this
# predicted: home  label: home
# predicted: by  label: by
# predicted: horror  label: horror
# predicted: haunted  label: haunted
# predicted: tell  label: tell
# predicted: me  label: me
# predicted: truly  label: truly
# predicted: i  label: i
# predicted: implore  label: implore
# predicted: is  label: is
# predicted: there  label: there
# predicted: is  label: is
# predicted: there  label: there
# predicted: balm  label: balm
# predicted: in  label: in
# predicted: gilead  label: gilead
# predicted: tell  label: tell
# predicted: me  label: me
# predicted: tell  label: tell
# predicted: me  label: me
# predicted: i  label: i
# predicted: implore  label: implore
# predicted: quoth  label: quoth
# predicted: the  label: the
# predicted: raven  label: raven
# predicted: nevermore  label: nevermore
# predicted: prophet  label: prophet
# predicted: said  label: said
# predicted: i  label: i
# predicted: thing  label: thing
# predicted: of  label: of
# predicted: evil  label: evil
# predicted: prophet  label: prophet
# predicted: still  label: still
# predicted: if  label: if
# predicted: bird  label: bird
# predicted: or  label: or
# predicted: devil  label: devil
# predicted: by  label: by
# predicted: that  label: that
# predicted: heaven  label: heaven
# predicted: that  label: that
# predicted: bends  label: bends
# predicted: above  label: above
# predicted: us  label: us
# predicted: by  label: by
# predicted: that  label: that
# predicted: god  label: god
# predicted: we  label: we
# predicted: both  label: both
# predicted: adore  label: adore
# predicted: tell  label: tell
# predicted: this  label: this
# predicted: soul  label: soul
# predicted: with  label: with
# predicted: sorrow  label: sorrow
# predicted: laden  label: laden
# predicted: if  label: if
# predicted: within  label: within
# predicted: the  label: the
# predicted: distant  label: distant
# predicted: aidenn  label: aidenn
# predicted: it  label: it
# predicted: shall  label: shall
# predicted: clasp  label: clasp
# predicted: a  label: a
# predicted: sainted  label: sainted
# predicted: maiden  label: maiden
# predicted: whom  label: whom
# predicted: the  label: the
# predicted: angels  label: angels
# predicted: name  label: name
# predicted: lenore  label: lenore
# predicted: clasp  label: clasp
# predicted: a  label: a
# predicted: rare  label: rare
# predicted: and  label: and
# predicted: radiant  label: radiant
# predicted: maiden  label: maiden
# predicted: whom  label: whom
# predicted: the  label: the
# predicted: angels  label: angels
# predicted: name  label: name
# predicted: lenore  label: lenore
# predicted: quoth  label: quoth
# predicted: the  label: the
# predicted: raven  label: raven
# predicted: nevermore  label: nevermore
# predicted: be  label: be
# predicted: that  label: that
# predicted: word  label: word
# predicted: our  label: our
# predicted: sign  label: sign
# predicted: of  label: of
# predicted: parting  label: parting
# predicted: bird  label: bird
# predicted: or  label: or
# predicted: fiend  label: fiend
# predicted: i  label: i
# predicted: shrieked  label: shrieked
# predicted: upstarting  label: upstarting
# predicted: get  label: get
# predicted: thee  label: thee
# predicted: back  label: back
# predicted: into  label: into
# predicted: the  label: the
# predicted: tempest  label: tempest
# predicted: and  label: and
# predicted: the  label: the
# predicted: night  label: night
# predicted: plutonian  label: plutonian
# predicted: shore  label: shore
# predicted: leave  label: leave
# predicted: no  label: no
# predicted: black  label: black
# predicted: plume  label: plume
# predicted: as  label: as
# predicted: a  label: a
# predicted: token  label: token
# predicted: of  label: of
# predicted: that  label: that
# predicted: lie  label: lie
# predicted: thy  label: thy
# predicted: soul  label: soul
# predicted: hath  label: hath
# predicted: spoken  label: spoken
# predicted: leave  label: leave
# predicted: my  label: my
# predicted: loneliness  label: loneliness
# predicted: unbroken  label: unbroken
# predicted: quit  label: quit
# predicted: the  label: the
# predicted: bust  label: bust
# predicted: above  label: above
# predicted: my  label: my
# predicted: door  label: door
# predicted: take  label: take
# predicted: thy  label: thy
# predicted: beak  label: beak
# predicted: from  label: from
# predicted: out  label: out
# predicted: my  label: my
# predicted: heart  label: heart
# predicted: and  label: and
# predicted: take  label: take
# predicted: thy  label: thy
# predicted: form  label: form
# predicted: from  label: from
# predicted: off  label: off
# predicted: my  label: my
# predicted: door  label: door
# predicted: quoth  label: quoth
# predicted: the  label: the
# predicted: raven  label: raven
# predicted: nevermore  label: nevermore
# predicted: and  label: and
# predicted: the  label: the
# predicted: raven  label: raven
# predicted: never  label: never
# predicted: flitting  label: flitting
# predicted: still  label: still
# predicted: is  label: is
# predicted: sitting  label: sitting
# predicted: still  label: still
# predicted: is  label: is
# predicted: sitting  label: sitting
# predicted: on  label: on
# predicted: the  label: the
# predicted: pallid  label: pallid
# predicted: bust  label: bust
# predicted: of  label: of
# predicted: pallas  label: pallas
# predicted: just  label: just
# predicted: above  label: above
# predicted: my  label: my
# predicted: chamber  label: chamber
# predicted: door  label: door
# predicted: and  label: and
# predicted: his  label: his
# predicted: eyes  label: eyes
# predicted: have  label: have
# predicted: all  label: all
# predicted: the  label: the
# predicted: seeming  label: seeming
# predicted: of  label: of
# predicted: a  label: a
# predicted: demon  label: demon
# predicted: that  label: that
# predicted: is  label: is
# predicted: dreaming  label: dreaming
# predicted: and  label: and
# predicted: the  label: the
# predicted: lamp-light  label: lamp-light
# predicted: over  label: over
# predicted: him  label: him
# predicted: streaming  label: streaming
# predicted: throws  label: throws
# predicted: his  label: his
# predicted: shadow  label: shadow
# predicted: on  label: on
# predicted: the  label: the
# predicted: floor  label: floor
# predicted: and  label: and
# predicted: my  label: my
# predicted: soul  label: soul
# predicted: from  label: from
# predicted: out  label: out
# predicted: that  label: that
# predicted: shadow  label: shadow
# predicted: that  label: that
# predicted: lies  label: lies
# predicted: floating  label: floating
# predicted: on  label: on
# predicted: the  label: the
# predicted: floor  label: floor
# predicted: shall  label: shall
# predicted: be  label: be
# Accuracy: 99.8% (1083/1085)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

def showPlot(points, title):
    plt.figure()
    fig, ax = plt.subplots()
    plt.plot(points)

showPlot(cbow_losses, 'CBOW Losses')

# %% [markdown]
# We've now trained an embedding using the continuous bag of words model. Below, we also show code for training the opposite model - the skipgram model - where you predict the context words based on a target word.
#
# Note how simple the SkipGram network is. There are no linear layers - just the embedding layer, and the training simply aims to maximize the dot product of embeddings of the target and embedding words.

# %%
# Tuple of a word (the target) to a word (a context word)
def create_skipgram_dataset(text):
    import random
    data = []
    for i in range(2, len(text) - 2):
        data.append((text[i], text[i-2], 1))
        data.append((text[i], text[i-1], 1))
        data.append((text[i], text[i+1], 1))
        data.append((text[i], text[i+2], 1))
        # negative sampling
        for _ in range(4):
            if random.random() < 0.5 or i >= len(text) - 3:
                rand_id = random.randint(0, i-1)
            else:
                rand_id = random.randint(i+3, len(text)-1)
            data.append((text[i], text[rand_id], 0))
    return data

skipgram_train = create_skipgram_dataset(text)
print('skipgram sample', skipgram_train[0])
# Out:
# skipgram sample ('a', 'once', 1)

# %%
class SkipGram(nn.Module):
    def __init__(self, vocab_size, embd_size):
        super(SkipGram, self).__init__()
        self.embeddings = nn.Embedding(vocab_size, embd_size)
    
    def forward(self, focus, context):
        embed_target = self.embeddings(focus).view((1, -1))
        embed_context = self.embeddings(context).view((1, -1))
        score = torch.mm(embed_target, torch.t(embed_context))
        log_probs = F.logsigmoid(score)
    
        return log_probs

# %%
def train_skipgram():
    losses = []
    loss_fn = nn.MSELoss()
    model = SkipGram(vocab_size, embd_size)
    print(model)
    optimizer = optim.SGD(model.parameters(), lr=learning_rate)
    
    for epoch in range(n_epoch):
        total_loss = .0
        print("epoch: ", epoch+1)
        for in_w, out_w, target in skipgram_train:
            # convert a target word and context word to index
            in_w_num = torch.LongTensor([w2i[in_w]])
            out_w_num = torch.LongTensor([w2i[out_w]])
            
            # run target and context through model
            model.zero_grad()
            log_probs = model(in_w_num, out_w_num)
            loss = loss_fn(log_probs[0], torch.Tensor([target]))
            
            # take step
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
        losses.append(total_loss)
        print("Loss: ", total_loss)
    return model, losses
    
sg_model, sg_losses = train_skipgram()
# Out:
# SkipGram(
#   (embeddings): Embedding(435, 100)
# )
# epoch:  1
# Loss:  150512.54457750372
# epoch:  2
# Loss:  6254.490208105832
# epoch:  3
# Loss:  4357.25856299564
# epoch:  4
# Loss:  4351.332062385759
# epoch:  5
# Loss:  4349.407155844588
# epoch:  6
# Loss:  4348.137793039561
# epoch:  7
# Loss:  4347.2208096520235
# epoch:  8
# Loss:  4346.519862427976
# epoch:  9
# Loss:  4345.962776565628
# epoch:  10
# Loss:  4345.507105687406
# epoch:  11
# Loss:  4345.126050112074
# epoch:  12
# Loss:  4344.801755728244
# epoch:  13
# Loss:  4344.521765085855
# epoch:  14
# Loss:  4344.277134428344
# epoch:  15
# Loss:  4344.061225391024
# epoch:  16
# Loss:  4343.869013179854
# epoch:  17
# Loss:  4343.69660470205
# epoch:  18
# Loss:  4343.540948102737
# epoch:  19
# Loss:  4343.399586259447
# epoch:  20
# Loss:  4343.270546457365
# epoch:  21
# Loss:  4343.152211619795
# epoch:  22
# Loss:  4343.043237081072
# epoch:  23
# Loss:  4342.9425036925195
# epoch:  24
# Loss:  4342.849067040968
# epoch:  25
# Loss:  4342.762128072943
# epoch:  26
# Loss:  4342.681004520575
# epoch:  27
# Loss:  4342.605091563445
# epoch:  28
# Loss:  4342.533889897538
# epoch:  29
# Loss:  4342.46695324463
# epoch:  30
# Loss:  4342.4038928498385

# %%
def test_skipgram(test_data, model):
    print('====Test SkipGram===')
    correct_ct = 0
    for in_w, out_w, target in test_data:
        in_w_var = torch.LongTensor([w2i[in_w]])
        out_w_var = torch.LongTensor([w2i[out_w]])

        model.zero_grad()
        log_probs = model(in_w_var, out_w_var)
        _, predicted = torch.max(log_probs, 1)
        predicted = predicted.item()
        if predicted == target:
            correct_ct += 1

    print('Accuracy: {:.1f}% ({:d}/{:d})'.format(correct_ct/len(test_data)*100, correct_ct, len(test_data)))

test_skipgram(skipgram_train, sg_model)
showPlot(sg_losses, 'SkipGram Losses')
# Out:
# ====Test SkipGram===
# Accuracy: 50.0% (4340/8680)

# %%
# RNN that uses an embedding layer and an LSTM Layer
# The emedding will be taken from the Skip Gram model
class RNN(nn.Module):
    def __init__(self, vocab_size, embd_size, embed):
        super(RNN, self).__init__()
        self.lstm_size = embd_size
        self.num_layers = 3

        self.embedding = embed

        self.lstm = nn.LSTM(
            input_size=self.lstm_size,
            hidden_size=self.lstm_size,
            num_layers=self.num_layers,
            dropout=0.2,
        )
        self.fc = nn.Linear(self.lstm_size, vocab_size)

    def forward(self, x, prev_state):
        embed = self.embedding(x)
        output, state = self.lstm(embed, prev_state)
        logits = self.fc(output)
        return logits, state

    def init_state(self, sequence_length):
        return (torch.zeros(self.num_layers, sequence_length, self.lstm_size),
                torch.zeros(self.num_layers, sequence_length, self.lstm_size))

# %%
model = RNN(vocab_size, embd_size, sg_model.embeddings)

word = "volume"
tok = torch.LongTensor([w2i[word]]).view(1, 1)

state = model.init_state(1)

for i in range(10):
    print(word)
    logits, state = model(tok, state)
    _, predicted = torch.max(logits.view(1,-1), 1)
    word = i2w[predicted.item()]
    start = torch.LongTensor([w2i[word]]).view(1, 1)
# Out:
# volume
# lining
# seeming
# seeming
# seeming
# seeming
# seeming
# seeming
# lining
# seeming
